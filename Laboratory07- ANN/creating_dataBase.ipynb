# %%
import itertools

# Imports
import pandas as pd
import numpy as np
import os
import random
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# %% [markdown]
# # Sepia Filter

# %%
def apply_sepia_filter(image):
    width, height = image.size
    pixels = image.load()  # Create the pixel map
    for py in range(height):
        for px in range(width):
            r, g, b = image.getpixel((px, py))
            tr = int(0.393 * r + 0.769 * g + 0.189 * b)
            tg = int(0.349 * r + 0.686 * g + 0.168 * b)
            tb = int(0.272 * r + 0.534 * g + 0.131 * b)
            tr = min(255, tr)
            tg = min(255, tg)
            tb = min(255, tb)
            pixels[px, py] = (tr, tg, tb)
    return image

# %% [markdown]
# # Generate Images with / without Sepia Filter

# %%
def generate_images(image_dir, image_base):
    images = os.listdir(image_dir)
    random.shuffle(images)  # Shuffle to randomize which images get the filter
    sepia_indices = np.random.choice(len(images), len(images) // 2, replace=False)
    data_for_csv = []
    for index, filename in enumerate(images):
        file_path = image_dir + '/' + filename
        try:
            image = Image.open(file_path)  # Attempt to open the image
        except IOError:
            continue  # Skip files that are not images

        is_sepia = 0
        if index in sepia_indices:
            image = apply_sepia_filter(image)
            sepia_file_path = image_base + '/' + f"sepia_{filename}"
            print(sepia_file_path)
            image.save(sepia_file_path)
            file_path = sepia_file_path
            print('!')
            is_sepia = 1
        else:
            non_sepia_file_path = f"{image_base}/not_sepia_{filename}"
            print(non_sepia_file_path)
            image.save(non_sepia_file_path)
            file_path = non_sepia_file_path
            print('!!')

        data_for_csv.append([file_path, is_sepia])

    # Save to CSV
    df = pd.DataFrame(data_for_csv, columns=['file_path', 'is_sepia'])
    csv_path = 'image_labels.csv'
    df.to_csv(csv_path, index=False)
    print(f"Data saved to {csv_path}")
    print(df.values)

# %%
def delete_all_images(image_base):
    for filename in os.listdir(image_base):
        if filename.startswith('sepia_') or filename.startswith('not_sepia_'):
            os.remove(f"{image_base}/{filename}")

# %%
delete_all_images(image_base='images')

# %%
generate_images('images/trainingBaseData', 'images')
# Out:
# images/not_sepia_image_235.jpeg
# !!
# images/not_sepia_image_237.jpeg
# !!
# images/sepia_image_175.jpeg
# !
# images/sepia_image_182.jpeg
# !
# images/sepia_image_174.jpeg
# !
# images/sepia_image_240.jpeg
# !
# images/sepia_image_222.jpeg
# !
# images/not_sepia_image_227.jpeg
# !!
# images/sepia_image_262.jpeg
# !
# images/sepia_image_211.jpeg
# !
# images/not_sepia_image_189.jpeg
# !!
# images/not_sepia_image_217.jpeg
# !!
# images/not_sepia_image_193.jpeg
# !!
# images/not_sepia_image_255.jpeg
# !!
# images/not_sepia_image_209.jpeg
# !!
# images/not_sepia_image_226.jpeg
# !!
# images/sepia_image_187.jpeg
# !
# images/sepia_image_245.jpeg
# !
# images/sepia_image_225.jpeg
# !
# images/sepia_image_177.jpeg
# !
# images/sepia_image_185.jpeg
# !
# images/sepia_image_186.jpeg
# !
# images/sepia_image_192.jpeg
# !
# images/not_sepia_image_188.jpeg
# !!
# Data saved to image_labels.csv
# [['images/not_sepia_image_235.jpeg' 0]
#  ['images/not_sepia_image_237.jpeg' 0]
#  ['images/sepia_image_175.jpeg' 1]
#  ['images/sepia_image_182.jpeg' 1]
#  ['images/sepia_image_174.jpeg' 1]
#  ['images/sepia_image_240.jpeg' 1]
#  ['images/sepia_image_222.jpeg' 1]
#  ['images/not_sepia_image_227.jpeg' 0]
#  ['images/sepia_image_262.jpeg' 1]
#  ['images/sepia_image_211.jpeg' 1]
#  ['images/not_sepia_image_189.jpeg' 0]
#  ['images/not_sepia_image_217.jpeg' 0]
#  ['images/not_sepia_image_193.jpeg' 0]
#  ['images/not_sepia_image_255.jpeg' 0]
#  ['images/not_sepia_image_209.jpeg' 0]
#  ['images/not_sepia_image_226.jpeg' 0]
#  ['images/sepia_image_187.jpeg' 1]
#  ['images/sepia_image_245.jpeg' 1]
#  ['images/sepia_image_225.jpeg' 1]
#  ['images/not_sepia_image_196.jpeg' 0]
#  ['images/not_sepia_image_257.jpeg' 0]
#  ['images/sepia_image_213.jpeg' 1]
#  ['images/sepia_image_232.jpeg' 1]
#  ['images/sepia_image_221.jpeg' 1]
#  ['images/not_sepia_image_180.jpeg' 0]
#  ['images/sepia_image_184.jpeg' 1]
#  ['images/not_sepia_image_204.jpeg' 0]
#  ['images/not_sepia_image_179.jpeg' 0]
#  ['images/sepia_image_241.jpeg' 1]
#  ['images/sepia_image_261.jpeg' 1]
#  ['images/not_sepia_image_238.jpeg' 0]
#  ['images/sepia_image_214.jpeg' 1]
#  ['images/not_sepia_image_243.jpeg' 0]
#  ['images/not_sepia_image_183.jpeg' 0]
#  ['images/not_sepia_image_190.jpeg' 0]
#  ['images/not_sepia_image_198.jpeg' 0]
#  ['images/sepia_image_236.jpeg' 1]
#  ['images/sepia_image_220.jpeg' 1]
#  ['images/not_sepia_image_200.jpeg' 0]
#  ['images/sepia_image_250.jpeg' 1]
#  ['images/not_sepia_image_253.jpeg' 0]
#  ['images/sepia_image_201.jpeg' 1]
#  ['images/sepia_image_249.jpeg' 1]
#  ['images/not_sepia_image_248.jpeg' 0]
#  ['images/not_sepia_image_259.jpeg' 0]
#  ['images/not_sepia_image_246.jpeg' 0]
#  ['images/sepia_image_252.jpeg' 1]
#  ['images/sepia_image_239.jpeg' 1]
#  ['images/sepia_image_202.jpeg' 1]
#  ['images/not_sepia_image_233.jpeg' 0]
#  ['images/sepia_image_216.jpeg' 1]
#  ['images/not_sepia_image_197.jpeg' 0]
#  ['images/sepia_image_254.jpeg' 1]
#  ['images/sepia_image_199.jpeg' 1]
#  ['images/not_sepia_image_256.jpeg' 0]
#  ['images/sepia_image_218.jpeg' 1]
#  ['images/sepia_image_230.jpeg' 1]
#  ['images/sepia_image_247.jpeg' 1]
#  ['images/sepia_image_263.jpeg' 1]
#  ['images/sepia_image_244.jpeg' 1]
#  ['images/not_sepia_image_181.jpeg' 0]
#  ['images/sepia_image_251.jpeg' 1]
#  ['images/sepia_image_195.jpeg' 1]
#  ['images/not_sepia_image_228.jpeg' 0]
#  ['images/sepia_image_219.jpeg' 1]
#  ['images/not_sepia_image_223.jpeg' 0]
#  ['images/not_sepia_image_191.jpeg' 0]
#  ['images/not_sepia_image_206.jpeg' 0]
#  ['images/not_sepia_image_215.jpeg' 0]
#  ['images/sepia_image_224.jpeg' 1]
#  ['images/sepia_image_242.jpeg' 1]
#  ['images/not_sepia_image_210.jpeg' 0]
#  ['images/sepia_image_212.jpeg' 1]
#  ['images/sepia_image_176.jpeg' 1]
#  ['images/sepia_image_194.jpeg' 1]
#  ['images/not_sepia_image_229.jpeg' 0]
#  ['images/not_sepia_image_178.jpeg' 0]
#  ['images/not_sepia_image_234.jpeg' 0]
#  ['images/not_sepia_image_258.jpeg' 0]
#  ['images/not_sepia_image_231.jpeg' 0]
#  ['images/not_sepia_image_260.jpeg' 0]
#  ['images/not_sepia_image_207.jpeg' 0]
#  ['images/not_sepia_image_205.jpeg' 0]
#  ['images/not_sepia_image_203.jpeg' 0]
#  ['images/not_sepia_image_208.jpeg' 0]
#  ['images/sepia_image_177.jpeg' 1]
#  ['images/sepia_image_185.jpeg' 1]
#  ['images/sepia_image_186.jpeg' 1]
#  ['images/sepia_image_192.jpeg' 1]
#  ['images/not_sepia_image_188.jpeg' 0]]

# %%
def print_images_in_grid(image_type, image_dir, grid_width=5):
    if image_type == 'sepia':
        images = [f for f in os.listdir(image_dir) if f.startswith('sepia_')]
    else:
        images = [f for f in os.listdir(image_dir) if f.startswith('not_sepia_')]

    random.shuffle(images)  # Shuffle the list to display random images

    # Calculate grid size
    if len(images) < grid_width:
        grid_width = len(images)
    grid_height = int(len(images) / grid_width) + (len(images) % grid_width > 0)

    # Create figure with sub-plots
    fig, axes = plt.subplots(grid_height, grid_width, figsize=(grid_width * 3, grid_height * 3))

    # Add each image to the sub-plot
    for i, ax in enumerate(axes.flat):
        if i < len(images):
            img_path = os.path.join(image_dir, images[i])
            img = Image.open(img_path)
            ax.imshow(img)
            ax.set_title(images[i])
            ax.axis('off')  # Hide the axes ticks
        else:
            ax.axis('off')  # Hide the axes ticks if no more images

    plt.show()  # Display the figure with images

# %%
image_dire='images'
